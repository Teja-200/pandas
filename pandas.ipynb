# %% [markdown]
# <a href="https://colab.research.google.com/github/Teja-200/pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas

# %%
import pandas as pd
data = {
    "Student_ID": [101, 102, 103, 104, 105],
    "Name": ["Teja", "Rahul", "Anjali", "Sita", "Aman"],
    "Age": [20, 21, 19, 22, 20],
    "Branch": ["CSE", "ECE", "IT", "CSE", "EEE"],
    "Marks": [85, 90, 78, 88, 92]
}
df = pd.DataFrame(data)
df
# Out:
#    Student_ID    Name  Age Branch  Marks
# 0         101    Teja   20    CSE     85
# 1         102   Rahul   21    ECE     90
# 2         103  Anjali   19     IT     78
# 3         104    Sita   22    CSE     88
# 4         105    Aman   20    EEE     92

# %%
df.head(3)
# Out:
#    Student_ID    Name  Age Branch  Marks
# 0         101    Teja   20    CSE     85
# 1         102   Rahul   21    ECE     90
# 2         103  Anjali   19     IT     78

# %%
data1 = {
    "Name": ["Teja", "Rahul", "Anjali", "Sita"],
    "Branch": ["CSE", "ECE", "IT", "CSE"],
    "Sem1_Marks": [85, 78, 90, 88]
}

df1 = pd.DataFrame(data1)

data2 = {
    "Name": ["Teja", "Rahul", "Anjali", "Sita"],
    "Age": [20, 21, 19, 22],
    "City": ["Hyderabad", "Bangalore", "Chennai", "Mumbai"]
}

df2 = pd.DataFrame(data2)

# %%
data_merge= pd.merge(df1,df2, on='Name')

# %%
data_merge
# Out:
#      Name Branch  Sem1_Marks  Age       City
# 0    Teja    CSE          85   20  Hyderabad
# 1   Rahul    ECE          78   21  Bangalore
# 2  Anjali     IT          90   19    Chennai
# 3    Sita    CSE          88   22     Mumbai

# %%
movie_set = pd.read_csv('Movies_dataset.csv')

# %%
movie_set
# Out:
#           id             original_title original_language  \
# 0        278   The Shawshank Redemption                en
# 1        238              The Godfather                en
# 2        240      The Godfather Part II                en
# 3        424           Schindler's List                en
# 4        389               12 Angry Men                en
# ...      ...                        ...               ...
# 9995  226486                      Tammy                en
# 9996   47964     A Good Day to Die Hard                en
# 9997  203835  Amityville: The Awakening                en
# 9998   43552    Vanishing on 7th Street                en
# 9999   80304           Casa de Mi Padre                en
#
#                           genre  \
# 0                  Drama, Crime
# 1                  Drama, Crime
# 2                  Drama, Crime
# 3           Drama, History, War
# 4                         Drama
# ...                         ...
# 9995                     Comedy
# ...

# %%
movie_set.iloc[10:20]
# Out:
#         id                                 original_title original_language  \
# 10     122  The Lord of the Rings: The Return of the King                en
# 11     680                                   Pulp Fiction                en
# 12  372058                                          君の名は。                ja
# 13     429                Il buono, il brutto, il cattivo                it
# 14  157336                                   Interstellar                en
# 15      13                                   Forrest Gump                en
# 16     769                                     GoodFellas                en
# 17     346                                           七人の侍                ja
# 18   12477                                          火垂るの墓                ja
# 19     637                                La vita è bella                it
#
#                                 genre  \
# 10         Adventure, Fantasy, Action
# 11            Thriller, Crime, Comedy
# ...

# %%
movie_set.describe()
# Out:
#                  id    popularity    vote_count  vote_average
# count  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean   2.212515e+05      4.603044   2063.779600      6.714658
# std    2.931349e+05      8.043705   3289.281439      0.672304
# min    2.000000e+00      0.003300    300.000000      5.300000
# 25%    1.032150e+04      2.069625    473.000000      6.200000
# 50%    4.144250e+04      3.527850    863.000000      6.700000
# 75%    3.998520e+05      5.345425   2064.250000      7.200000
# max    1.426776e+06    441.551500  38436.000000      8.714000

# %%
movie_set.head(10)
# Out:
#        id                original_title original_language  \
# 0     278      The Shawshank Redemption                en
# 1     238                 The Godfather                en
# 2     240         The Godfather Part II                en
# 3     424              Schindler's List                en
# 4     389                  12 Angry Men                en
# 5     129                      千と千尋の神隠し                ja
# 6     155               The Dark Knight                en
# 7   19404  दिलवाले दुल्हनिया ले जायेंगे                hi
# 8     497                The Green Mile                en
# 9  496243                           기생충                ko
#
#                             genre  \
# 0                    Drama, Crime
# 1                    Drama, Crime
# 2                    Drama, Crime
# 3             Drama, History, War
# 4                           Drama
# 5      Animation, Family, Fantasy
# 6  Drama, Action, Crime, Thriller
# 7          Comedy, Drama, Romance
# ...

# %%
movie_set.shape
# Out:
# (10000, 9)

# %%
movie_set.columns
# Out:
# Index(['id', 'original_title', 'original_language', 'genre', 'overview',
#        'popularity', 'vote_count', 'vote_average', 'release_date'],
#       dtype='object')

# %%
movie_set.dtypes
# Out:
# id                     int64
# original_title        object
# original_language     object
# genre                 object
# overview              object
# popularity           float64
# vote_count             int64
# vote_average         float64
# release_date          object
# dtype: object

# %%
movie_set.loc[movie_set['genre'] == 'Drama']
# Out:
#            id                   original_title original_language  genre  \
# 4         389                     12 Angry Men                en  Drama
# 28        510  One Flew Over the Cuckoo's Nest                en  Drama
# 31     255709                               소원                ko  Drama
# 44    1058694                          Radical                es  Drama
# 49         73               American History X                en  Drama
# ...       ...                              ...               ...    ...
# 9522   254302                        High-Rise                en  Drama
# 9597   164251                           Serena                en  Drama
# 9615    10802                        Showgirls                en  Drama
# 9733     1665                        Last Days                en  Drama
# 9836    87368                        17 filles                fr  Drama
#
#                                                overview  popularity  \
# ...
